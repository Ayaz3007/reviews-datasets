# %%
import nltk
import pandas as pd
import pyarrow.parquet as pq
import pyarrow as pa
import fastparquet
import re
import pymorphy2
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from pyarrow.parquet import ParquetFile

#приводим в стандартной форме слова
morph = pymorphy2.MorphAnalyzer()
def morph_analyzer(text):
    ps=nltk.porter.PorterStemmer()
    text= ' '.join([morph.parse(word)[0].normal_form for word in text.split()])
    return text

#оставляем только слова
def remove_special_characters(text, remove_digits=True):
    pattern=r'[^\u0401\u0451\u0410-\u044fa-zA-z0-9\s]'
    text=re.sub(pattern,'',text)
    return text

tokenizer=ToktokTokenizer()
stopword_list=nltk.corpus.stopwords.words('russian')

#удаляем ненужные слова
def remove_stopwords(text, is_lower_case=False):
    print("remove_stopwords")
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

data_reviews = pd.read_parquet(r"C:\Users\Admin\Downloads\train.parquet")
data_reviews['text']=data_reviews['text'].apply(remove_stopwords)
data_reviews['text']=data_reviews['text'].apply(morph_analyzer)
data_reviews['text']=data_reviews['text'].apply(remove_special_characters)
norm_train_reviews = data_reviews
norm_train_reviews.to_parquet('norm_train_reviews.parquet', engine='fastparquet')

data_test_reviews = pd.read_parquet(r"C:\Users\Admin\Downloads\test.parquet")
data_test_reviews['text']=data_test_reviews['text'].apply(remove_stopwords)
data_test_reviews['text']=data_test_reviews['text'].apply(morph_analyzer)
data_test_reviews['text']=data_test_reviews['text'].apply(remove_special_characters)
norm_test_reviews = data_test_reviews
norm_test_reviews.to_parquet('norm_test_reviews.parquet', engine='fastparquet')
# Out:
#                                                     text  labels label_name
# 0      Смотрел данный фильм ещё в глубоком детстве. И...       1   negative
# 1      После того, как третья часть оригинальной исто...       0   positive
# 2      Сериал очень нравится. Смотрела все три сезона...       0   positive
# 3      Лично мне понравилось. Конечно не шедевр, но в...       0   positive
# 4      Неторопливая интеллигентная английская драма и...       0   positive
# ...                                                  ...     ...        ...
# 73815  На Новый год купила себе книгу 'Прекрасные соз...       1   negative
# 73816  Данный фильм считается чуть ли не киношедевром...       1   negative
# 73817  Стараюсь смотреть всё, что связано с религией ...       1   negative
# 73818  Сначала о том немногом хорошем, что есть в фил...       1   negative
# 73819  Я несколько раз читала роман `Прокаженная`, ещ...       0   positive
#
# [73820 rows x 3 columns]
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# ...
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# remove_stopwords
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 47
#      44 data_reviews = pd.read_parquet(r"C:\Users\Admin\Downloads\train.parquet")
#      45 print(data_reviews)
# ---> 47 data_reviews['text']=data_reviews['text'].apply(remove_stopwords)
#      48 data_reviews['text']=data_reviews['text'].apply(morph_analyzer)
#      49 data_reviews['text']=data_reviews['text'].apply(remove_special_characters)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py:4626, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4516 def apply(
#    4517     self,
#    4518     func: AggFuncType,
#    (...)
#    4521     **kwargs,
#    4522 ) -> DataFrame | Series:
#    4523     """
#    4524     Invoke function on values of Series.
#    4525
#    (...)
#    4624     dtype: float64
#    4625     """
# -> 4626     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[3], line 34, in remove_stopwords(text, is_lower_case)
#      32 def remove_stopwords(text, is_lower_case=False):
#      33     print("remove_stopwords")
# ---> 34     tokens = tokenizer.tokenize(text)
#      35     tokens = [token.strip() for token in tokens]
#      36     if is_lower_case:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\nltk\tokenize\toktok.py:175, in ToktokTokenizer.tokenize(self, text, return_str)
#     173 text = str(text)  # Converts input string into unicode.
#     174 for regexp, substitution in self.TOKTOK_REGEXES:
# --> 175     text = regexp.sub(substitution, text)
#     176 # Finally, strips heading and trailing spaces
#     177 # and converts output string into unicode.
#     178 text = str(text.strip())
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\re.py:332, in _subx.<locals>.filter(match, template)
#     331 def filter(match, template=template):
# --> 332     return sre_parse.expand_template(template, match)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\sre_parse.py:1061, in expand_template(template, match)
#    1059 try:
#    1060     for index, group in groups:
# -> 1061         literals[index] = g(group) or empty
#    1062 except IndexError:
#    1063     raise error("invalid group reference %d" % index)
#
# KeyboardInterrupt:
